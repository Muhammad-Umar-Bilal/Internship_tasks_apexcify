# %%
import pandas as pd
import random

# Define satisfaction levels
levels = ["Very Satisfied", "Satisfied", "Neutral", "Dissatisfied", "Very Dissatisfied"]

# Generate 50 random survey responses with more balanced distribution
responses = random.choices(
    levels, 
    weights=[0.25, 0.30, 0.20, 0.15, 0.10],  # optimized distribution
    k=50
)

# Create DataFrame
df = pd.DataFrame({"Satisfaction": responses})

# Save to CSV
df = pd.read_csv("survey_data_optimized.csv")

# Show sample and counts
df.head(), df["Satisfaction"].value_counts(), file_path
# Out:
# (     Satisfaction
#  0       Satisfied
#  1  Very Satisfied
#  2         Neutral
#  3       Satisfied
#  4    Dissatisfied,
#  Satisfaction
#  Very Satisfied       16
#  Satisfied            13
#  Neutral               8
#  Dissatisfied          8
#  Very Dissatisfied     5
#  Name: count, dtype: int64,
#  '/mnt/data/survey_data_optimized.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load dataset
df = pd.read_csv("survey_data_optimized.csv")

# Step 2: Count satisfaction levels
satisfaction_counts = df["Satisfaction"].value_counts()

print("Survey Results:\n", satisfaction_counts)

# Step 3: Plot bar chart
plt.figure(figsize=(8,5))
sns.barplot(x=satisfaction_counts.index, y=satisfaction_counts.values, palette="Blues_d")

plt.xlabel("Satisfaction Level")
plt.ylabel("Number of Responses")
plt.title("Survey Results - User Satisfaction Levels")
plt.show()
# Out:
# Survey Results:
#  Satisfaction
# Very Satisfied       16
# Satisfied            13
# Neutral               8
# Dissatisfied          8
# Very Dissatisfied     5
# Name: count, dtype: int64
# C:\Users\HP 840 G6\AppData\Local\Temp\ipykernel_7032\3964178494.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=satisfaction_counts.index, y=satisfaction_counts.values, palette="Blues_d")
